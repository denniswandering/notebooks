# %%
# %%writefile cifar10_32326410_train_gcn.prototxt
# name: "CIFAR10_32326410_train_gcn"
# layers{
#     name:"cifar"
#     type: DATA
#     top: "data"
#     top: "label"
#     data_param{
#         source: "/data/sichen/data/cifar_gcn_leveldb/cifar-train-leveldb"
#         mean_file: "/data/sichen/data/cifar_gcn_mean.binaryproto"
#         batch_size: 100
#     }
# }
# layers{
#     name: "conv1"
#     type: CONVOLUTION
#     bottom: "data"
#     top: "conv1"
#     blobs_lr:1
#     blobs_lr:2
#     convolution_param{
#         num_output:32
#         pad:2
#         kernel_size:5
#         stride:1
#         weight_filler{
#         	type: "gaussian"
#         	std: 0.05
#         }
#         bias_filler{
#         	type: "constant"
#         }
#     }
# }
# layers{
# 	name: "pool1"
# 	type: POOLING
# 	bottom: "conv1"
# 	top: "pool1"
# 	pooling_param{
# 		pool:MAX
# 		kernel_size:3
# 		stride:2
# 	}
#
# }
# layers{
# 	name:"relu1"
# 	type:RELU
# 	bottom:"pool1"
# 	top:"pool1"
# }
# layers{
#     name: "conv2"
#     type: CONVOLUTION
#     bottom: "pool1"
#     top: "conv2"
#     blobs_lr:1
#     blobs_lr:2
#     convolution_param{
#         num_output:32
#         pad:2
#         kernel_size:5
#         stride:1
#         weight_filler{
#         	type: "gaussian"
#         	std: 0.05
#         }
#         bias_filler{
#         	type: "constant"
#             value: 0
#         }
#     }
# }
# layers{
# 	name: "pool2"
# 	type: POOLING
# 	bottom: "conv2"
# 	top: "pool2"
# 	pooling_param{
# 		pool:AVE
# 		kernel_size:3
# 		stride:2
# 	}
# }
# layers{
# 	name:"relu2"
# 	type:RELU
# 	bottom:"pool2"
# 	top:"pool2"
# }
# layers{
#     name: "conv3"
#     type: CONVOLUTION
#     bottom: "pool2"
#     top: "conv3"
#     blobs_lr:1
#     blobs_lr:2
#     convolution_param{
#         num_output:64
#         pad:2
#         kernel_size:5
#         stride:1
#         weight_filler{
#         	type: "gaussian"
#         	std: 0.05
#         }
#         bias_filler{
#         	type: "constant"
#             value: 0
#         }
#     }
# }
# layers{
# 	name: "pool3"
# 	type: POOLING
# 	bottom: "conv3"
# 	top: "pool3"
# 	pooling_param{
# 		pool:AVE
# 		kernel_size:3
# 		stride:2
# 	}
# }
# layers{
# 	name:"relu3"
# 	type:RELU
# 	bottom:"pool3"
# 	top:"pool3"
# }
# layers{
# 	name: "ip1"
# 	type: INNER_PRODUCT
# 	bottom: "pool3"
# 	top: "ip1"
# 	blobs_lr: 0.1
# 	blobs_lr: 0.2
# 	inner_product_param{
# 		num_output: 10
# 		weight_filler{
# 			type: "gaussian"
# 			std:0.05
# 		}
# 		bias_filler{
# 			type: "constant"
# 		}
# 	}
# }
# layers{
# 	name: "loss"
# 	type: SOFTMAX_LOSS
# 	bottom: "ip1"
# 	bottom: "label"
# }
# Out:
# Writing cifar10_32326410_train_gcn.prototxt

# %%
# %%writefile cifar10_32326410_test_gcn.prototxt
# name: "CIFAR10_32326410_test_gcn"
# layers{
#     name:"cifar"
#     type: DATA
#     top: "data"
#     top: "label"
#     data_param{
#         source: "/data/sichen/data/cifar_gcn_leveldb/cifar-test-leveldb"
#         mean_file: "/data/sichen/data/cifar_gcn_mean.binaryproto"
#         batch_size: 100
#     }
# }
# layers{
#     name: "conv1"
#     type: CONVOLUTION
#     bottom: "data"
#     top: "conv1"
#     blobs_lr:1
#     blobs_lr:2
#     convolution_param{
#         num_output:32
#         pad:2
#         kernel_size:5
#         stride:1
#         weight_filler{
#         	type: "gaussian"
#         	std: 0.05
#         }
#         bias_filler{
#         	type: "constant"
#         }
#     }
# }
# layers{
# 	name: "pool1"
# 	type: POOLING
# 	bottom: "conv1"
# 	top: "pool1"
# 	pooling_param{
# 		pool:MAX
# 		kernel_size:3
# 		stride:2
# 	}
#
# }
# layers{
# 	name:"relu1"
# 	type:RELU
# 	bottom:"pool1"
# 	top:"pool1"
# }
# layers{
#     name: "conv2"
#     type: CONVOLUTION
#     bottom: "pool1"
#     top: "conv2"
#     blobs_lr:1
#     blobs_lr:2
#     convolution_param{
#         num_output:32
#         pad:2
#         kernel_size:5
#         stride:1
#         weight_filler{
#         	type: "gaussian"
#         	std: 0.05
#         }
#         bias_filler{
#         	type: "constant"
#         }
#     }
# }
# layers{
# 	name: "pool2"
# 	type: POOLING
# 	bottom: "conv2"
# 	top: "pool2"
# 	pooling_param{
# 		pool:AVE
# 		kernel_size:3
# 		stride:2
# 	}
# }
# layers{
# 	name:"relu2"
# 	type:RELU
# 	bottom:"pool2"
# 	top:"pool2"
# }
# layers{
#     name: "conv3"
#     type: CONVOLUTION
#     bottom: "pool2"
#     top: "conv3"
#     blobs_lr:1
#     blobs_lr:2
#     convolution_param{
#         num_output:64
#         pad:2
#         kernel_size:5
#         stride:1
#         weight_filler{
#         	type: "gaussian"
#         	std: 0.05
#         }
#         bias_filler{
#         	type: "constant"
#         }
#     }
# }
# layers{
# 	name: "pool3"
# 	type: POOLING
# 	bottom: "conv3"
# 	top: "pool3"
# 	pooling_param{
# 		pool:AVE
# 		kernel_size:3
# 		stride:2
# 	}
# }
# layers{
# 	name:"relu3"
# 	type:RELU
# 	bottom:"pool3"
# 	top:"pool3"
# }
# layers{
# 	name: "ip1"
# 	type: INNER_PRODUCT
# 	bottom: "pool3"
# 	top: "ip1"
# 	blobs_lr: 0.1
# 	blobs_lr: 0.2
# 	inner_product_param{
# 		num_output: 10
# 		weight_filler{
# 			type: "gaussian"
# 			std:0.05
# 		}
# 		bias_filler{
# 			type: "constant"
# 		}
# 	}
# }
# layers{
# 	name: "prob"
# 	type: SOFTMAX
# 	bottom: "ip1"
#     top: "prob"
# }
# layers{
#     name: "accuracy"
#     type: ACCURACY
#     bottom: "prob"
#     bottom: "label"
#     top: "accuracy"
# }
# Out:
# Writing cifar10_32326410_test_gcn.prototxt

# %%
# %%writefile cifar10_32326410_solver_gcn.prototxt
# train_net: "cifar10_32326410_train_gcn.prototxt"
# test_net: "cifar10_32326410_test_gcn.prototxt"
# test_iter: 100
# test_interval: 1000
# base_lr: 0.025
# momentum: 0.9
# weight_decay: 0.0005
# lr_policy: "fixed"
# display: 100
# max_iter: 40000
# snapshot: 5000
# snapshot_prefix:"cifar10_32326410_gcn"
# solver_mode: GPU
# info{
#     type:"weight"
#     interval: 1000
# }
# Out:
# Writing cifar10_32326410_solver_gcn.prototxt

# %%
# %%writefile train_323264_gcn.sh
# export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/usr/local/lib
# TOOLS=/home/chensi/my_caffe/build/tools
# GLOG_logtostderr=1 $TOOLS/train_net.bin cifar10_32326410_solver_gcn.prototxt
# Out:
# Writing train_323264_gcn.sh
