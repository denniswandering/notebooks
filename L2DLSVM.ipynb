# %%
folder_name = 'dlsvml2'
# Out:
# /bin/sh: NAME: command not found

# %%
import os

# %%
os.mkdir(folder_name)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-28-db7ca0f9a306> in <module>()
# ----> 1 os.mkdir(folder_name)
#
# OSError: [Errno 17] File exists: 'dlsvml2'

# %%
# %%writefile /data/sichen/ipython_notebooks/dlsvml2/train.prototxt
# name: "train"
# layers{
#     name:"cifar"
#     type: DATA
#     top: "data"
#     top: "label"
#     data_param{
#         source: "/data/sichen/data/cifar10-leveldb/cifar-train-leveldb"
#         mean_file: "/data/sichen/data/cifar_mean.binaryproto"
#         batch_size: 100
#     }
# }
# layers{
#     name: "conv1"
#     type: CONVOLUTION
#     bottom: "data"
#     top: "conv1"
#     blobs_lr:1
#     blobs_lr:2
#     convolution_param{
#         num_output:32
#         pad:2
#         kernel_size:5
#         stride:1
#         weight_filler{
#         	type: "gaussian"
#         	std: 0.0001
#         }
#         bias_filler{
#         	type: "constant"
#         }
#     }
# }
# layers{
# 	name:"relu1"
# 	type:RELU
# 	bottom:"conv1"
# 	top:"conv1"
# }
# layers{
# 	name: "pool1"
# 	type: POOLING
# 	bottom: "conv1"
# 	top: "pool1"
# 	pooling_param{
# 		pool:MAX
# 		kernel_size:3
# 		stride:2
# 	}
# }
#
# layers{
#     name: "conv2"
#     type: CONVOLUTION
#     bottom: "pool1"
#     top: "conv2"
#     blobs_lr:1
#     blobs_lr:2
#     convolution_param{
#         num_output:32
#         pad:2
#         kernel_size:5
#         stride:1
#         weight_filler{
#         	type: "gaussian"
#         	std: 0.01
#         }
#         bias_filler{
#         	type: "constant"
#         }
#     }
# }
# layers{
# 	name:"relu2"
# 	type:RELU
# 	bottom:"conv2"
# 	top:"conv2"
# }
# layers{
# 	name: "pool2"
# 	type: POOLING
# 	bottom: "conv2"
# 	top: "pool2"
# 	pooling_param{
# 		pool:AVE
# 		kernel_size:3
# 		stride:2
# 	}
# }
#
# layers{
#     name: "conv3"
#     type: CONVOLUTION
#     bottom: "pool2"
#     top: "conv3"
#     blobs_lr:1
#     blobs_lr:2
#     convolution_param{
#         num_output:64
#         pad:2
#         kernel_size:5
#         stride:1
#         weight_filler{
#         	type: "gaussian"
#         	std: 0.01
#         }
#         bias_filler{
#         	type: "constant"
#         }
#     }
# }
# layers{
# 	name:"relu3"
# 	type:RELU
# 	bottom:"conv3"
# 	top:"conv3"
# }
# layers{
# 	name: "pool3"
# 	type: POOLING
# 	bottom: "conv3"
# 	top: "pool3"
# 	pooling_param{
# 		pool:AVE
# 		kernel_size:3
# 		stride:2
# 	}
# }
#
# layers{
# 	name: "ip1"
# 	type: INNER_PRODUCT
# 	bottom: "pool3"
# 	top: "ip1"
# 	blobs_lr: 0.5
# 	blobs_lr: 1
#     weight_decay: 100
#     weight_decay: 0
# 	inner_product_param{
# 		num_output: 10
# 		weight_filler{
# 			type: "gaussian"
# 			std:0.01
# 		}
# 		bias_filler{
# 			type: "constant"
# 		}
# 	}
# }
# layers{
# 	name: "loss"
# 	type: HINGE_LOSS
#     hinge_loss_param{
#         hinge_norm: L2
#     }
# 	bottom: "ip1"
# 	bottom: "label"
# }
# Out:
# Overwriting /data/sichen/ipython_notebooks/dlsvml2/train.prototxt

# %%
# %%writefile /data/sichen/ipython_notebooks/dlsvml2/test.prototxt
# name: "test"
# layers{
#     name:"cifar"
#     type: DATA
#     top: "data"
#     top: "label"
#     data_param{
#         source: "/data/sichen/data/cifar10-leveldb/cifar-test-leveldb"
#         mean_file: "/data/sichen/data/cifar_mean.binaryproto"
#         batch_size: 100
#     }
# }
# layers{
#     name: "conv1"
#     type: CONVOLUTION
#     bottom: "data"
#     top: "conv1"
#     blobs_lr:1
#     blobs_lr:2
#     convolution_param{
#         num_output:32
#         pad:2
#         kernel_size:5
#         stride:1
#         weight_filler{
#         	type: "gaussian"
#         	std: 0.0001
#         }
#         bias_filler{
#         	type: "constant"
#         }
#     }
# }
# layers{
# 	name:"relu1"
# 	type:RELU
# 	bottom:"conv1"
# 	top:"conv1"
# }
# layers{
# 	name: "pool1"
# 	type: POOLING
# 	bottom: "conv1"
# 	top: "pool1"
# 	pooling_param{
# 		pool:MAX
# 		kernel_size:3
# 		stride:2
# 	}
# }
#
# layers{
#     name: "conv2"
#     type: CONVOLUTION
#     bottom: "pool1"
#     top: "conv2"
#     blobs_lr:1
#     blobs_lr:2
#     convolution_param{
#         num_output:32
#         pad:2
#         kernel_size:5
#         stride:1
#         weight_filler{
#         	type: "gaussian"
#         	std: 0.01
#         }
#         bias_filler{
#         	type: "constant"
#         }
#     }
# }
# layers{
# 	name:"relu2"
# 	type:RELU
# 	bottom:"conv2"
# 	top:"conv2"
# }
# layers{
# 	name: "pool2"
# 	type: POOLING
# 	bottom: "conv2"
# 	top: "pool2"
# 	pooling_param{
# 		pool:AVE
# 		kernel_size:3
# 		stride:2
# 	}
# }
#
# layers{
#     name: "conv3"
#     type: CONVOLUTION
#     bottom: "pool2"
#     top: "conv3"
#     blobs_lr:1
#     blobs_lr:2
#     convolution_param{
#         num_output:64
#         pad:2
#         kernel_size:5
#         stride:1
#         weight_filler{
#         	type: "gaussian"
#         	std: 0.01
#         }
#         bias_filler{
#         	type: "constant"
#         }
#     }
# }
# layers{
# 	name:"relu3"
# 	type:RELU
# 	bottom:"conv3"
# 	top:"conv3"
# }
# layers{
# 	name: "pool3"
# 	type: POOLING
# 	bottom: "conv3"
# 	top: "pool3"
# 	pooling_param{
# 		pool:AVE
# 		kernel_size:3
# 		stride:2
# 	}
# }
#
# layers{
# 	name: "ip1"
# 	type: INNER_PRODUCT
# 	bottom: "pool3"
# 	top: "ip1"
# 	blobs_lr: 1
# 	blobs_lr: 2
#     weight_decay: 750
#     weight_decay: 0
# 	inner_product_param{
# 		num_output: 10
# 		weight_filler{
# 			type: "gaussian"
# 			std:0.01
# 		}
# 		bias_filler{
# 			type: "constant"
# 		}
# 	}
# }
# layers{
# 	name: "prob"
# 	type: SOFTMAX
# 	bottom: "ip1"
#     top: "prob"
# }
# layers{
#     name: "accuracy"
#     type: ACCURACY
#     bottom: "prob"
#     bottom: "label"
#     top: "accuracy"
# }
# Out:
# Overwriting /data/sichen/ipython_notebooks/dlsvml2/test.prototxt

# %%
# %%writefile /data/sichen/ipython_notebooks/dlsvml2/solver.prototxt
# train_net: "train.prototxt"
# test_net: "test.prototxt"
# test_iter: 100
# test_interval: 500
# base_lr: 0.001
# momentum: 0.9
# weight_decay: 0.004
# lr_policy: "fixed"
# display: 100
# max_iter: 50000
# snapshot: 5000
# snapshot_prefix:"/home/chensi/mylocal/sichen/data/solver_states/dlsvml2"
# solver_mode: GPU
# info{
#     type:"weight"
#     interval: 500
# }
# Out:
# Overwriting /data/sichen/ipython_notebooks/dlsvml2/solver.prototxt

# %%
# %%writefile /data/sichen/ipython_notebooks/dlsvml2/train.sh
# export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/usr/local/lib
# TOOLS=/home/chensi/my_caffe/build/tools
# GLOG_logtostderr=1 $TOOLS/train_net.bin solver.prototxt
# Out:
# Overwriting /data/sichen/ipython_notebooks/dlsvml2/train.sh

# %%
# %%writefile /data/sichen/ipython_notebooks/dlsvml2/resume_train.sh
# export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/usr/local/lib
# TOOLS=/home/chensi/my_caffe/build/tools
# SOL_STAT=/home/chensi/mylocal/sichen/data/solver_states
# GLOG_logtostderr=1 $TOOLS/train_net.bin solver.prototxt $SOL_STAT/dlsvm_iter_20000.solverstate
# Out:
# Overwriting /data/sichen/ipython_notebooks/dlsvml2/resume_train.sh
